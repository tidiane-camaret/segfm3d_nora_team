# %%
from src.config import config
import os
img_dir = os.path.join(config["DATA_DIR"], "3D_val_npz")
gts_dir = os.path.join(config["DATA_DIR"], "3D_val_gt_interactive_seg")
output_dir = os.path.join(config["RESULTS_DIR"], "simple")
# Out:
# Loaded configuration for machine: nora

# %%
import pandas as pd
import os
import glob

# Path to your folder containing CSV files
folder_path = "/nfs/data/nii/data1/Analysis/GPUnet/ANALYSIS_segfm-robin/data/model-checkpoints/new-dataset/fold_0"  # Replace with your actual folder path

# Get all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

print("DSC Statistics for each file:")
print("-" * 50)

for file_path in csv_files:
    # Get just the filename for display
    filename = os.path.basename(file_path)
    
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Calculate mean and std for hard_dsc column
    mean_dsc = df['hard_dsc'].mean()
    std_dsc = df['hard_dsc'].std()
    
    print(f"{filename}:")
    print(f"  Mean: {mean_dsc:.6f}")
    print(f"  Std:  {std_dsc:.6f}")
    print()
# Out:
# DSC Statistics for each file:
# --------------------------------------------------
# test_results_6_2025-05-30_08-30-43-999.csv:
#   Mean: 0.792588
#   Std:  0.153001
#
# test_results_1_2025-05-30_10-08-10-999.csv:
#   Mean: 0.800270
#   Std:  0.136387
#
# test_results_2_2025-05-30_05-25-01-016.csv:
#   Mean: 0.785795
#   Std:  0.146185
#
# test_results_1_2025-05-30_04-38-36-364.csv:
#   Mean: 0.800122
#   Std:  0.124131
#
# test_results_0_2025-05-30_03-52-18-351.csv:
#   Mean: 0.776089
#   Std:  0.147205
#
# test_results_3_2025-05-30_06-11-17-965.csv:
#   Mean: 0.790332
#   Std:  0.148698
#
# test_results_4_2025-05-30_06-57-57-657.csv:
#   Mean: 0.788713
#   Std:  0.134043
#
# test_results_0_2025-05-30_09-21-19-609.csv:
#   Mean: 0.795171
#   Std:  0.140324
#
# test_results_5_2025-05-30_07-44-18-169.csv:
#   Mean: 0.796395
#   Std:  0.148492

# %%
# get list of processed cases
processed_cases = sorted([f for f in os.listdir(output_dir) if f.endswith(".npz")])
len(processed_cases)
# Out:
# 1868

# %%
import numpy as np
import pandas as pd

evalmetrics_df = pd.read_csv(os.path.join(output_dir, "norateam_metrics.csv"))
evalmetrics_df.head()
len(evalmetrics_df)
# Out:
# 1864

# %%
# Extract first two letters from CaseName to create modality column
evalmetrics_df['modality'] = evalmetrics_df['CaseName'].str[:2]
# add a dsc progression ratio that is dsc_5/dsc_1
evalmetrics_df['dsc_progression_ratio'] = evalmetrics_df['DSC_Final'] / evalmetrics_df['DSC_1']
# add a nsd progression ratio that is nsd_5/nsd_1
evalmetrics_df['nsd_progression_ratio'] = evalmetrics_df['NSD_Final'] / evalmetrics_df['NSD_1']
# add a running time progression ratio that is running_time_1 / total_running_time
evalmetrics_df['running_time_iter_1_ratio'] = evalmetrics_df['RunningTime_1'] / evalmetrics_df['TotalRunningTime']

# %%
# plot DSC_Final boxplot by modality
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.boxplot(x='modality', y='DSC_Final', data=evalmetrics_df)
plt.title('DSC_Final Boxplot by Modality')
plt.xlabel('Modality')
plt.ylabel('DSC_Final')
plt.show()

# %%
from src.eval_metrics import ( 
    compute_multi_class_dsc,
    compute_multi_class_nsd,
)

# %%
dscs = []
nsds = []
spacings = []
shapes = []


for i, case_filename in enumerate(processed_cases):
    print(f"Processing {i+1}/{len(processed_cases)}: {case_filename}")
    gt_filepath = os.path.join(gts_dir, case_filename)
    gt_data = np.load(gt_filepath)
    gts = gt_data["gts"]
    spacing = gt_data["spacing"]
    shape = gts.shape


    case_name = os.path.splitext(case_filename)[0]
    dsc = df.loc[df['CaseName'] == case_name, 'DSC_Final'].values[0] if len(df.loc[df['CaseName'] == case_name, 'DSC_Final'].values) > 0 else 0
    nsd = df.loc[df['CaseName'] == case_name, 'NSD_Final'].values[0] if len(df.loc[df['CaseName'] == case_name, 'NSD_Final'].values) > 0 else 0
    dscs.append(dsc)
    nsds.append(nsd)
    
    shapes.append(shape)
    spacings.append(spacing)
# Out:
# Processing 1/1868: CT_AMOS_amos_0018.npz
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 17
#      13 shape = gts.shape
#      16 case_name = os.path.splitext(case_filename)[0]
# ---> 17 dsc = df.loc[df['CaseName'] == case_name, 'DSC_Final'].values[0] if len(df.loc[df['CaseName'] == case_name, 'DSC_Final'].values) > 0 else 0
#      18 nsd = df.loc[df['CaseName'] == case_name, 'NSD_Final'].values[0] if len(df.loc[df['CaseName'] == case_name, 'NSD_Final'].values) > 0 else 0
#      19 dscs.append(dsc)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
results_df = pd.DataFrame({
    'filename': processed_cases,
    'dsc': dscs,
    'nsd': nsds,
    'spacing': spacings,
    'shape': shapes
})
results_df.to_csv('segmentation_metrics_results.csv', index=False)

# %%
modalities = [p[:2] for p in processed_cases]

# %%
len(dscs), len(nsds), len(modalities), len(spacings), len(shapes)
# Out:
# (2070, 2070, 2070, 2070, 2070)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Convert spacings to a comparable metric (average spacing)
voxel_sizes = [np.prod(spacing) for spacing in spacings]
nb_voxels = [np.prod(shape) for shape in shapes]

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(voxel_sizes, dscs, alpha=0.7, s=50)

# Add labels and title
plt.xlabel('Average Spacing')
plt.ylabel('DSC Score')
plt.title('DSC vs Spacing')

# Add grid for better readability
plt.grid(True, alpha=0.3)

# Show plot
plt.tight_layout()
plt.show()

# %%
def plot_metrics(x_values, dscs, nsds, x_label):
    """Plot DSC and NSD on same graph with shared y-axis"""
    fig, ax = plt.subplots(figsize=(10, 6))
    
    # Plot DSC (blue) and NSD (red)
    ax.scatter(x_values, dscs, color='blue', alpha=0.7, label='DSC')
    ax.scatter(x_values, nsds, color='red', alpha=0.7, label='NSD')
    
    # Add trend lines
    ax.plot(x_values, np.poly1d(np.polyfit(x_values, dscs, 1))(x_values), 'b--', alpha=0.6)
    ax.plot(x_values, np.poly1d(np.polyfit(x_values, nsds, 1))(x_values), 'r--', alpha=0.6)
    
    # Labels and formatting
    ax.set_xlabel(x_label)
    ax.set_ylabel('Score Value')
    plt.title(f'DSC and NSD vs {x_label}')
    
    # Legend
    ax.legend(loc='best')
    
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # Print correlation stats
    dsc_corr = np.corrcoef(x_values, dscs)[0,1]
    nsd_corr = np.corrcoef(x_values, nsds)[0,1]
    print(f"DSC correlation with {x_label}: {dsc_corr:.3f}")
    print(f"NSD correlation with {x_label}: {nsd_corr:.3f}")

# %%
plot_metrics(voxel_sizes, dscs, nsds, 'voxel_size')
# Out:
# DSC correlation with voxel_size: 0.027
# NSD correlation with voxel_size: -0.000

# %%
plot_metrics(nb_voxels, dscs, nsds, 'number_of_voxels')
# Out:
# DSC correlation with number_of_voxels: 0.033
# NSD correlation with number_of_voxels: -0.155

# %%
anisotropy = [max(spacing) / min(spacing) for spacing in spacings]
plot_metrics(anisotropy, dscs, nsds, 'anisotropy')
# Out:
# DSC correlation with anisotropy: 0.020
# NSD correlation with anisotropy: 0.129

# %%
voxel_count = [np.prod(shape) for shape in shapes]
plot_metrics(voxel_count, dscs, nsds, 'voxel_count')
# Out:
# DSC correlation with voxel_count: 0.033
# NSD correlation with voxel_count: -0.155

# %%
def plot_stats_by_modality(modalities, dscs, nsds, voxel_sizes, voxel_counts):
    """
    Plot statistics by modality with direct modality list input.
    
    Parameters:
    modalities: list of strings - modality for each case (e.g., ['CT', 'MR', 'US', ...])
    dscs: list of floats - DSC values
    nsds: list of floats - NSD values
    voxel_sizes: list of floats - voxel size for each case
    voxel_counts: list of floats - voxel count for each case
    """
    import matplotlib.pyplot as plt
    import numpy as np
    from collections import defaultdict
    
    # Group metrics by modality
    modality_dscs = defaultdict(list)
    modality_nsds = defaultdict(list)
    modality_voxel_sizes = defaultdict(list)
    modality_voxel_counts = defaultdict(list)
    
    for mod, dsc, nsd, v_size, v_count in zip(modalities, dscs, nsds, voxel_sizes, voxel_counts):
        modality_dscs[mod].append(dsc)
        modality_nsds[mod].append(nsd)
        modality_voxel_sizes[mod].append(v_size)
        modality_voxel_counts[mod].append(v_count)
    
    # Get unique modalities
    unique_mods = sorted(modality_dscs.keys())
    
    # Create figure with 2x2 subplots
    fig, axes = plt.subplots(2, 2, figsize=(18, 12))
    
    # For boxplots
    metric_data = {
        'DSC': [modality_dscs[mod] for mod in unique_mods],
        'NSD': [modality_nsds[mod] for mod in unique_mods],
        'Voxel Size': [modality_voxel_sizes[mod] for mod in unique_mods],
        'Voxel Count': [modality_voxel_counts[mod] for mod in unique_mods]
    }
    
    titles = ['DSC by Modality', 'NSD by Modality', 
              'Voxel Size by Modality', 'Voxel Count by Modality']
    ylabels = ['DSC Score', 'NSD Score', 'Voxel Size (mm³)', 'Voxel Count']
    
    # Colors for different modalities
    colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightyellow', 'lightgrey']
    
    # Create each subplot
    for i, (ax, title, ylabel, key) in enumerate(zip(
            axes.flatten(), titles, ylabels, metric_data.keys())):
        
        # Log scale for voxel count
        if key == 'Voxel Count':
            ax.set_yscale('log')
        
        # Create boxplot
        box = ax.boxplot(metric_data[key], patch_artist=True)
        ax.set_xticklabels(unique_mods)
        ax.set_title(title)
        ax.set_ylabel(ylabel)
        ax.grid(axis='y', alpha=0.3)
        
        # Add color to boxes
        for j, b in enumerate(box['boxes']):
            b.set(facecolor=colors[j % len(colors)])
    
    plt.tight_layout()
    plt.show()
    
    # Print statistics per modality
    print("Statistics by Modality:")
    print("-----------------------")
    
    for mod in unique_mods:
        print(f"\n{mod} Modality (n={len(modality_dscs[mod])}):")
        print(f"  DSC - Mean: {np.mean(modality_dscs[mod]):.3f}, Median: {np.median(modality_dscs[mod]):.3f}")
        print(f"  NSD - Mean: {np.mean(modality_nsds[mod]):.3f}, Median: {np.median(modality_nsds[mod]):.3f}")
        print(f"  Voxel Size - Mean: {np.mean(modality_voxel_sizes[mod]):.3f}, Median: {np.median(modality_voxel_sizes[mod]):.3f}")
        print(f"  Voxel Count - Mean: {np.mean(modality_voxel_counts[mod]):.3f}, Median: {np.median(modality_voxel_counts[mod]):.3f}")

# %%
plot_stats_by_modality(modalities, dscs, nsds, voxel_sizes, voxel_count)
# Out:
# Statistics by Modality:
# -----------------------
#
# CT Modality (n=906):
#   DSC - Mean: 0.814, Median: 0.846
#   NSD - Mean: 0.853, Median: 0.888
#   Voxel Size - Mean: 2.621, Median: 3.375
#   Voxel Count - Mean: 20056636.223, Median: 13186047.000
#
# MR Modality (n=977):
#   DSC - Mean: 0.663, Median: 0.689
#   NSD - Mean: 0.765, Median: 0.798
#   Voxel Size - Mean: 3.184, Median: 1.000
#   Voxel Count - Mean: 2805040.160, Median: 2340884.000
#
# Mi Modality (n=8):
#   DSC - Mean: 0.637, Median: 0.656
#   NSD - Mean: 0.866, Median: 0.930
#   Voxel Size - Mean: 1.000, Median: 1.000
#   Voxel Count - Mean: 7806250.000, Median: 8730000.000
#
# PE Modality (n=69):
#   DSC - Mean: 0.707, Median: 0.729
#   NSD - Mean: 0.656, Median: 0.685
#   Voxel Size - Mean: 25.186, Median: 12.441
#   Voxel Count - Mean: 17641803.130, Median: 14240000.000
#
# US Modality (n=110):
#   DSC - Mean: 0.796, Median: 0.843
#   NSD - Mean: 0.797, Median: 0.842
#   Voxel Size - Mean: 0.088, Median: 0.095
#   Voxel Count - Mean: 40262989.927, Median: 5750071.000
