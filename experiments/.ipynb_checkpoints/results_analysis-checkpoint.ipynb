# %%
from src.config import config
import os
img_dir = os.path.join(config["DATA_DIR"], "3D_val_npz")
gts_dir = os.path.join(config["DATA_DIR"], "3D_val_gt_interactive_seg")
output_dir = os.path.join(config["RESULTS_DIR"], "nnint")
# Out:
# Loaded configuration for machine: nora

# %%
# get list of processed cases
processed_cases = sorted([f for f in os.listdir(output_dir) if f.endswith(".npz")])
len(processed_cases)
# Out:
# 2070

# %%
import numpy as np

processed_cases = np.random.choice(processed_cases, 500, replace=False)

# %%
from src.eval_metrics import ( 
    compute_multi_class_dsc,
    compute_multi_class_nsd,
)

# %%
dscs = []
nsds = []
spacings = []
shapes = []


for i, case_filename in enumerate(processed_cases):
    print(f"Processing {i+1}/{len(processed_cases)}: {case_filename}")
    gt_filepath = os.path.join(gts_dir, case_filename)
    gt_data = np.load(gt_filepath)
    gts = gt_data["gts"]
    spacing = gt_data["spacing"]
    spacings.append(spacing)
    shape = gts.shape
    shapes.append(shape)

    output_filepath = os.path.join(output_dir, case_filename)
    output_data = np.load(output_filepath)
    preds = output_data["segs"]
    
    dsc = compute_multi_class_dsc(gts, preds)
                # compute nsd
    if dsc > 0.2:
        # only compute nsd when dice > 0.2 because NSD is also low when dice is too low
        nsd = compute_multi_class_nsd(gts, preds, spacing)
    else:
        nsd = 0.0  # Assume model performs poor on this sample
    dscs.append(dsc)
    nsds.append(nsd)
# Out:
# Processing 1/500: CT_totalseg-vertebrae_s0446.npz
# Processing 2/500: MR_BraTS-T2w_bratsgli_1103.npz
# Processing 3/500: CT_TotalSeg_muscles_s0326.npz
# Processing 4/500: MR_ProstateT2_NCI-Prostate3T-01-0023.npz
# Processing 5/500: US_Cardiac_patient0231_2CH_half_sequence.npz
# Processing 6/500: CT_TotalSeg_muscles_s0820.npz
# Processing 7/500: US_Cardiac_patient0251_2CH_half_sequence.npz
# Processing 8/500: MR_WMH_FLAIR_Utrecht_32.npz
# Processing 9/500: MR_BraTS-T1c_bratsgli_0178.npz
# Processing 10/500: CT_TotalSeg_muscles_s1029.npz
# Processing 11/500: US_Cardiac_patient0194_2CH_half_sequence.npz
# Processing 12/500: MR_BraTS-T1n_bratsgli_0656.npz
# Processing 13/500: CT_AbdomenAtlas_BDMAP_00003854.npz
# Processing 14/500: CT_TotalSeg_muscles_s0608.npz
# Processing 15/500: MR_BraTS-T2w_bratsgli_0995.npz
# Processing 16/500: CT_LNQ_LymphNode-0064.npz
# Processing 17/500: MR_BraTS-T1c_bratsgli_0393.npz
# Processing 18/500: MR_Spider_31_t1_ivd.npz
# Processing 19/500: MR_BraTS-T2f_bratsgli_0349.npz
# Processing 20/500: CT_LungMasks_LUNG1-111.npz
# Processing 21/500: US_Cardiac_patient0254_4CH_half_sequence.npz
# Processing 22/500: CT_AbdTumor_PETCT_3b1c9155f5.npz
# Processing 23/500: MR_WMH_FLAIR_Utrecht_2.npz
# Processing 24/500: CT_GTVpNCCT_segrap_0020.npz
# Processing 25/500: CT_TotalSeg_muscles_s0436.npz
# Processing 26/500: MR_BraTS-T2f_bratsgli_1096.npz
# Processing 27/500: MR_WMH_FLAIR_Utrecht_16.npz
# Processing 28/500: CT_TotalSeg_muscles_s1000.npz
# Processing 29/500: MR_BraTS-T1c_bratsgli_1187.npz
# Processing 30/500: PET_autoPET_fdg_6170317f2e_02-18-2000-NA-PET-CT Ganzkoerper  primaer mit KM-94274.npz
# Processing 31/500: CT_AbdTumor_Adrenal_Ki67_Seg_004.npz
# Processing 32/500: CT_AbdomenAtlas_BDMAP_00004662.npz
# Processing 33/500: CT_AbdTumor_case_00542.npz
# Processing 34/500: CT_GTVpNCCT_segrap_0028.npz
# Processing 35/500: US_Cardiac_patient0242_4CH_half_sequence.npz
# Processing 36/500: CT_AbdomenAtlas_BDMAP_00003222.npz
# Processing 37/500: CT_COVID-19-20-CT-SegChallenge_volume-covid19-A-0228.npz
# Processing 38/500: MR_BraTS-T1n_bratsgli_0272.npz
# Processing 39/500: CT_TotalSeg_cardiac_s0377.npz
# Processing 40/500: MR_heart-ACDC_ACDC_patient104_frame01_myo.npz
# Processing 41/500: MR_totalseg_mr_s0153.npz
# Processing 42/500: MR_ISLES2022_DWI_sub-strokecase0124.npz
# Processing 43/500: CT_TotalSeg_muscles_s1077.npz
# Processing 44/500: CT_AbdTumor_hepaticvessel_282.npz
# Processing 45/500: PET_autoPET_fdg_ca89066e44_08-11-2005-NA-PET-CT Ganzkoerper  primaer mit KM-64009.npz
# Processing 46/500: MR_BraTS-T1c_bratsgli_1245.npz
# Processing 47/500: CT_LNQ_LymphNode-0509.npz
# Processing 48/500: MR_BraTS-T1n_bratsgli_1291.npz
# Processing 49/500: MR_BraTS-T1c_bratsgli_1282.npz
# Processing 50/500: CT_TotalSeg_organs_s1294.npz
# Processing 51/500: MR_BraTS-T2w_bratsgli_0321.npz
# Processing 52/500: MR_BraTS-T2w_bratsgli_1278.npz
# Processing 53/500: CT_TotalSeg_organs_s0236.npz
# Processing 54/500: MR_crossmoda_crossmoda2023_ukm_3_ceT1.npz
# Processing 55/500: CT_AbdTumor_Adrenal_Ki67_Seg_030.npz
# Processing 56/500: CT_AbdTumor_pancreas_051.npz
# Processing 57/500: CT_AbdomenAtlas_BDMAP_00002737.npz
# Processing 58/500: US_Cardiac_patient0219_2CH_half_sequence.npz
# Processing 59/500: MR_BraTS-T1n_bratsgli_0194.npz
# Processing 60/500: MR_totalseg_mr_s0147.npz
# Processing 61/500: CT_totalseg-vertebrae_s0328.npz
# Processing 62/500: PET_autoPET_fdg_ebb0045704_09-27-2002-NA-Unspecified CT-08213.npz
# Processing 63/500: CT_GTVpEnhance_segrap_0043.npz
# Processing 64/500: MR_totalseg_mr_s0113.npz
# Processing 65/500: CT_TotalSeg_muscles_s1195.npz
# Processing 66/500: MR_WMH_FLAIR_Singapore_56.npz
# Processing 67/500: MR_WMH_FLAIR_Utrecht_47.npz
# Processing 68/500: CT_TotalSeg_muscles_s0140.npz
# Processing 69/500: MR_ProstateT2_T2-ProstateX-0105.npz
# Processing 70/500: MR_BraTS-T2w_bratsgli_0270.npz
# Processing 71/500: MR_Spider_11_t2_ivd.npz
# Processing 72/500: MR_Spider_45_t1_ivd.npz
# Processing 73/500: CT_LungLesions_lung_092.npz
# Processing 74/500: PET_autoPET_psma_44b93bfe059935a1_2014-06-07.npz
# Processing 75/500: MR_Spider_5_t2_vet.npz
# Processing 76/500: MR_BraTS-T1c_bratsgli_1249.npz
# Processing 77/500: CT_TotalSeg_cardiac_s0836.npz
# Processing 78/500: CT_AbdomenAtlas_BDMAP_00007447.npz
# Processing 79/500: CT_TotalSeg_organs_s1069.npz
# Processing 80/500: CT_AbdomenAtlas_BDMAP_00001855.npz
# Processing 81/500: MR_BraTS-T1c_bratsgli_0198.npz
# Processing 82/500: CT_TotalSeg_cardiac_s0480.npz
# Processing 83/500: CT_totalseg-vertebrae_s0959.npz
# Processing 84/500: MR_ISLES2022_DWI_sub-strokecase0168.npz
# Processing 85/500: CT_AMOS_amos_0249.npz
# Processing 86/500: CT_TotalSeg_cardiac_s0204.npz
# Processing 87/500: MR_heart-ACDC_ACDC_patient006_frame01_myo.npz
# Processing 88/500: MR_BraTS-T1n_bratsgli_0593.npz
# Processing 89/500: CT_TotalSeg_muscles_s0667.npz
# Processing 90/500: MR_heart-ACDC_ACDC_patient027_frame01_myo.npz
# Processing 91/500: CT_AbdTumor_PETCT_27d69a8466.npz
# Processing 92/500: MR_BraTS-T2w_bratsgli_1230.npz
# Processing 93/500: CT_TotalSeg_muscles_s0867.npz
# Processing 94/500: MR_BraTS-T1c_bratsgli_1296.npz
# Processing 95/500: MR_Spider_214_t2_spi.npz
# Processing 96/500: MR_BraTS-T2f_bratsgli_1262.npz
# Processing 97/500: CT_TotalSeg_organs_s0525.npz
# Processing 98/500: MR_Spider_112_t1_ivd.npz
# Processing 99/500: CT_totalseg-vertebrae_s1292.npz
# Processing 100/500: US_Cardiac_patient0215_4CH_half_sequence.npz
# Processing 101/500: CT_AbdTumor_colon_032.npz
# Processing 102/500: MR_BraTS-T1n_bratsgli_0846.npz
# Processing 103/500: CT_TotalSeg_organs_s1043.npz
# Processing 104/500: MR_ProstateT2_T2-MSD-prostate_38.npz
# Processing 105/500: CT_TotalSeg_cardiac_s1075.npz
# Processing 106/500: MR_WMH_T1_Amsterdam_GE3T_109.npz
# Processing 107/500: CT_TotalSeg_cardiac_s0166.npz
# Processing 108/500: MR_BraTS-T1n_bratsgli_1167.npz
# Processing 109/500: CT_AMOS_amos_0158.npz
# Processing 110/500: CT_TotalSeg_muscles_s0381.npz
# Processing 111/500: MR_WMH_FLAIR_Amsterdam_GE3T_140.npz
# Processing 112/500: CT_TotalSeg_cardiac_s0753.npz
# Processing 113/500: MR_BraTS-T2w_bratsgli_0637.npz
# Processing 114/500: CT_TotalSeg_muscles_s0746.npz
# Processing 115/500: CT_TotalSeg_organs_s1137.npz
# Processing 116/500: CT_LungMasks_LUNG1-102.npz
# Processing 117/500: CT_TotalSeg_muscles_s0229.npz
# Processing 118/500: MR_Head_HNTSMRG24_148_preRT_T2.npz
# Processing 119/500: MR_BraTS-T1n_bratsgli_1298.npz
# Processing 120/500: MR_QIN-PROSTATE-Prostate_PCAMPMRI-00014_0_2_MR.npz
# Processing 121/500: MR_BraTS-T1n_bratsgli_0277.npz
# Processing 122/500: MR_ISLES2022_DWI_sub-strokecase0212.npz
# Processing 123/500: CT_TotalSeg_organs_s0446.npz
# Processing 124/500: MR_Spider_8_t2_ivd.npz
# Processing 125/500: MR_Head_HNTSMRG24_8_preRT_T2.npz
# Processing 126/500: MR_BraTS-T1c_bratsgli_0821.npz
# Processing 127/500: MR_WMH_FLAIR_Utrecht_17.npz
# Processing 128/500: MR_BraTS-T1n_bratsgli_0489.npz
# Processing 129/500: CT_TotalSeg_muscles_s0978.npz
# Processing 130/500: MR_BraTS-T2w_bratsgli_0611.npz
# Processing 131/500: CT_AbdomenAtlas_BDMAP_00008267.npz
# Processing 132/500: MR_BraTS-T2f_bratsgli_0626.npz
# Processing 133/500: MR_totalseg_mr_s0194.npz
# Processing 134/500: CT_TotalSeg_cardiac_s1228.npz
# Processing 135/500: CT_AbdTumor_hepaticvessel_278.npz
# Processing 136/500: CT_AbdomenAtlas_BDMAP_00004506.npz
# Processing 137/500: MR_BraTS-T2f_bratsgli_0771.npz
# Processing 138/500: CT_TotalSeg_muscles_s1115.npz
# Processing 139/500: MR_BraTS-T2f_bratsgli_0883.npz
# Processing 140/500: CT_TotalSeg_organs_s0721.npz
# Processing 141/500: CT_TotalSeg_cardiac_s1286.npz
# Processing 142/500: MR_BraTS-T2f_bratsgli_1071.npz
# Processing 143/500: CT_AbdTumor_hepaticvessel_367.npz
# Processing 144/500: CT_TotalSeg_cardiac_s0423.npz
# Processing 145/500: MR_BraTS-T2f_bratsgli_0107.npz
# Processing 146/500: PET_autoPET_fdg_465176d213_05-16-2002-NA-PET-CT Ganzkoerper  primaer mit KM-77090.npz
# Processing 147/500: CT_TotalSeg_muscles_s0821.npz
# Processing 148/500: CT_TotalSeg_muscles_s0455.npz
# Processing 149/500: MR_BraTS-T2w_bratsgli_0788.npz
# Processing 150/500: MR_Spider_75_t1_ivd.npz
# Processing 151/500: MR_BraTS-T2w_bratsgli_0052.npz
# Processing 152/500: MR_Spider_225_t2_vet.npz
# Processing 153/500: CT_totalseg-vertebrae_s0109.npz
# Processing 154/500: MR_BraTS-T1c_bratsgli_0110.npz
# Processing 155/500: MR_BraTS-T1c_bratsgli_0156.npz
# Processing 156/500: MR_BraTS-T1c_bratsgli_1308.npz
# Processing 157/500: MR_BraTS-T2f_bratsgli_0577.npz
# Processing 158/500: CT_TotalSeg_cardiac_s1278.npz
# Processing 159/500: MR_BraTS-T1n_bratsgli_0430.npz
# Processing 160/500: CT_LungMasks_LUNG1-255.npz
# Processing 161/500: CT_TotalSeg_cardiac_s1274.npz
# Processing 162/500: US_Cardiac_patient0223_4CH_half_sequence.npz
# Processing 163/500: MR_heart-ACDC_ACDC_patient116_frame01_lvrv.npz
# Processing 164/500: MR_heart-ACDC_ACDC_patient110_frame11_lvrv.npz
# Processing 165/500: CT_AMOS_amos_0398.npz
# Processing 166/500: CT_AbdTumor_hepaticvessel_177.npz
# Processing 167/500: MR_BraTS-T2f_bratsgli_1204.npz
# Processing 168/500: MR_BraTS-T1n_bratsgli_0189.npz
# Processing 169/500: PET_autoPET_fdg_b327726c24_08-27-2000-NA-PET-CT Ganzkoerper  primaer mit KM-56109.npz
# Processing 170/500: CT_LungMasks_lung_026.npz
# Processing 171/500: MR_BraTS-T2f_bratsgli_0941.npz
# Processing 172/500: CT_AbdomenAtlas_BDMAP_00000454.npz
# Processing 173/500: MR_BraTS-T1n_bratsgli_0091.npz
# Processing 174/500: MR_Spider_237_t2_spi.npz
# Processing 175/500: US_Cardiac_patient0238_2CH_half_sequence.npz
# Processing 176/500: CT_AbdTumor_PETCT_ef9d41b836.npz
# Processing 177/500: MR_BraTS-T2w_bratsgli_1214.npz
# Processing 178/500: MR_Spider_144_t2_ivd.npz
# Processing 179/500: PET_autoPET_psma_01a52e26ce5b5e26_2016-11-21.npz
# Processing 180/500: MR_BraTS-T2f_bratsgli_0688.npz
# Processing 181/500: MR_BraTS-T1c_bratsgli_0698.npz
# Processing 182/500: MR_Spider_198_t1_spi.npz
# Processing 183/500: CT_AMOS_amos_0385.npz
# Processing 184/500: CT_TotalSeg_organs_s0960.npz
# Processing 185/500: MR_crossmoda_crossmoda2023_etz_20_ceT1.npz
# Processing 186/500: MR_BraTS-T1c_bratsgli_0935.npz
# Processing 187/500: MR_BraTS-T2f_bratsgli_0926.npz
# Processing 188/500: MR_WMH_T1_Singapore_68.npz
# Processing 189/500: CT_AbdTumor_case_00445.npz
# Processing 190/500: CT_TotalSeg_muscles_s0467.npz
# Processing 191/500: US_Cardiac_patient0228_2CH_half_sequence.npz
# Processing 192/500: CT_TotalSeg_organs_s1276.npz
# Processing 193/500: MR_BraTS-T1c_bratsgli_0834.npz
# Processing 194/500: MR_BraTS-T2f_bratsgli_0383.npz
# Processing 195/500: CT_GTVpEnhance_segrap_0069.npz
# Processing 196/500: CT_LungMasks_LUNG1-054.npz
# Processing 197/500: CT_AbdomenAtlas_BDMAP_00003673.npz
# Processing 198/500: MR_BraTS-T1n_bratsgli_0140.npz
# Processing 199/500: CT_TotalSeg_organs_s0431.npz
# Processing 200/500: MR_BraTS-T1c_bratsgli_1198.npz
# Processing 201/500: CT_AbdomenAtlas_BDMAP_00003464.npz
# Processing 202/500: MR_heart-ACDC_ACDC_patient123_frame11_lvrv.npz
# Processing 203/500: MR_Head_HNTSMRG24_70_midRT_T2.npz
# Processing 204/500: CT_AirwayTree_ATM_159.npz
# Processing 205/500: MR_BraTS-T2w_bratsgli_0294.npz
# Processing 206/500: CT_totalseg-vertebrae_s0102.npz
# Processing 207/500: CT_AbdTumor_hepaticvessel_200.npz
# Processing 208/500: MR_Head_HNTSMRG24_175_midRT_T2.npz
# Processing 209/500: CT_TotalSeg_cardiac_s0117.npz
# Processing 210/500: CT_LungMasks_LUNG1-265.npz
# Processing 211/500: CT_TotalSeg_muscles_s0937.npz
# Processing 212/500: CT_AbdTumor_liver_19.npz
# Processing 213/500: MR_BraTS-T1c_bratsgli_0377.npz
# Processing 214/500: CT_LNQ_LymphNode-0895.npz
# Processing 215/500: CT_AbdomenAtlas_BDMAP_00001616.npz
# Processing 216/500: MR_BraTS-T2w_bratsgli_0251.npz
# Processing 217/500: MR_BraTS-T2w_bratsgli_0811.npz
# Processing 218/500: CT_AbdTumor_PETCT_11e258cc1f.npz
# Processing 219/500: MR_Head_HNTSMRG24_169_preRT_T2.npz
# Processing 220/500: CT_totalseg-vertebrae_s0670.npz
# Processing 221/500: CT_TotalSeg_organs_s0977.npz
# Processing 222/500: CT_AbdTumor_case_00527.npz
# Processing 223/500: MR_BraTS-T1c_bratsgli_1277.npz
# Processing 224/500: US_Cardiac_patient0243_4CH_half_sequence.npz
# Processing 225/500: CT_AMOS_amos_0214.npz
# Processing 226/500: MR_WMH_T1_Amsterdam_GE3T_143.npz
# Processing 227/500: MR_heart-ACDC_ACDC_patient098_frame01_lvrv.npz
# Processing 228/500: US_Low-limb-Leg40.npz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 25
#      22             # compute nsd
#      23 if dsc > 0.2:
#      24     # only compute nsd when dice > 0.2 because NSD is also low when dice is too low
# ---> 25     nsd = compute_multi_class_nsd(gts, preds, spacing)
#      26 else:
#      27     nsd = 0.0  # Assume model performs poor on this sample
#
# File /nfs/norasys/notebooks/camaret/segfm3d_nora_team/src/eval_metrics.py:25, in compute_multi_class_nsd(gt, seg, spacing, tolerance)
#      23     gt_i = gt == i
#      24     seg_i = seg == i
# ---> 25     surface_distance = compute_surface_distances(
#      26         gt_i, seg_i, spacing_mm=spacing
#      27     )
#      28     nsd.append(compute_surface_dice_at_tolerance(surface_distance, tolerance))
#      29 return np.mean(nsd)
#
# File /software/anaconda3/envs/segfm3d_2/lib/python3.12/site-packages/surface_distance/metrics.py:282, in compute_surface_distances(mask_gt, mask_pred, spacing_mm)
#     278   distances_gt_to_pred, surfel_areas_gt = _sort_distances_surfels(
#     279       distances_gt_to_pred, surfel_areas_gt)
#     281 if distances_pred_to_gt.shape != (0,):
# --> 282   distances_pred_to_gt, surfel_areas_pred = _sort_distances_surfels(
#     283       distances_pred_to_gt, surfel_areas_pred)
#     285 return {
#     286     "distances_gt_to_pred": distances_gt_to_pred,
#     287     "distances_pred_to_gt": distances_pred_to_gt,
#     288     "surfel_areas_gt": surfel_areas_gt,
#     289     "surfel_areas_pred": surfel_areas_pred,
#     290 }
#
# File /software/anaconda3/envs/segfm3d_2/lib/python3.12/site-packages/surface_distance/metrics.py:132, in _sort_distances_surfels(distances, surfel_areas)
#     122 def _sort_distances_surfels(distances, surfel_areas):
#     123   """Sorts the two list with respect to the tuple of (distance, surfel_area).
#     124
#     125   Args:
#    (...)    130     A tuple of the sorted (distances, surfel_areas).
#     131   """
# --> 132   sorted_surfels = np.array(sorted(zip(distances, surfel_areas)))
#     133   return sorted_surfels[:, 0], sorted_surfels[:, 1]
#
# KeyboardInterrupt:

# %%
modalities = [p[:2] for p in processed_cases]
modalities = modalities[:len(dscs)]

# %%
len(dscs), len(nsds), len(modalities), len(spacings), len(shapes)
spacings = spacings[:len(dscs)]
shapes = shapes[:len(dscs)]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Convert spacings to a comparable metric (average spacing)
voxel_sizes = [np.prod(spacing) for spacing in spacings]
nb_voxels = [np.prod(shape) for shape in shapes]

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(voxel_sizes, dscs, alpha=0.7, s=50)

# Add labels and title
plt.xlabel('Average Spacing')
plt.ylabel('DSC Score')
plt.title('DSC vs Spacing')

# Add grid for better readability
plt.grid(True, alpha=0.3)

# Show plot
plt.tight_layout()
plt.show()

# %%
def plot_metrics(x_values, dscs, nsds, x_label):
    """Plot DSC and NSD on same graph with shared y-axis"""
    fig, ax = plt.subplots(figsize=(10, 6))
    
    # Plot DSC (blue) and NSD (red)
    ax.scatter(x_values, dscs, color='blue', alpha=0.7, label='DSC')
    ax.scatter(x_values, nsds, color='red', alpha=0.7, label='NSD')
    
    # Add trend lines
    ax.plot(x_values, np.poly1d(np.polyfit(x_values, dscs, 1))(x_values), 'b--', alpha=0.6)
    ax.plot(x_values, np.poly1d(np.polyfit(x_values, nsds, 1))(x_values), 'r--', alpha=0.6)
    
    # Labels and formatting
    ax.set_xlabel(x_label)
    ax.set_ylabel('Score Value')
    plt.title(f'DSC and NSD vs {x_label}')
    
    # Legend
    ax.legend(loc='best')
    
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # Print correlation stats
    dsc_corr = np.corrcoef(x_values, dscs)[0,1]
    nsd_corr = np.corrcoef(x_values, nsds)[0,1]
    print(f"DSC correlation with {x_label}: {dsc_corr:.3f}")
    print(f"NSD correlation with {x_label}: {nsd_corr:.3f}")

# %%
plot_metrics(voxel_sizes, dscs, nsds, 'voxel_size')
# Out:
# DSC correlation with voxel_size: -0.003
# NSD correlation with voxel_size: -0.038

# %%
plot_metrics(nb_voxels, dscs, nsds, 'number_of_voxels')
# Out:
# DSC correlation with number_of_voxels: 0.243
# NSD correlation with number_of_voxels: 0.092

# %%
anisotropy = [max(spacing) / min(spacing) for spacing in spacings]
plot_metrics(anisotropy, dscs, nsds, 'anisotropy')
# Out:
# DSC correlation with anisotropy: 0.063
# NSD correlation with anisotropy: 0.187

# %%
voxel_count = [np.prod(shape) for shape in shapes]
plot_metrics(voxel_count, dscs, nsds, 'voxel_count')
# Out:
# DSC correlation with voxel_count: 0.243
# NSD correlation with voxel_count: 0.092

# %%
def plot_stats_by_modality(modalities, dscs, nsds, voxel_sizes, voxel_counts):
    """
    Plot statistics by modality with direct modality list input.
    
    Parameters:
    modalities: list of strings - modality for each case (e.g., ['CT', 'MR', 'US', ...])
    dscs: list of floats - DSC values
    nsds: list of floats - NSD values
    voxel_sizes: list of floats - voxel size for each case
    voxel_counts: list of floats - voxel count for each case
    """
    import matplotlib.pyplot as plt
    import numpy as np
    from collections import defaultdict
    
    # Group metrics by modality
    modality_dscs = defaultdict(list)
    modality_nsds = defaultdict(list)
    modality_voxel_sizes = defaultdict(list)
    modality_voxel_counts = defaultdict(list)
    
    for mod, dsc, nsd, v_size, v_count in zip(modalities, dscs, nsds, voxel_sizes, voxel_counts):
        modality_dscs[mod].append(dsc)
        modality_nsds[mod].append(nsd)
        modality_voxel_sizes[mod].append(v_size)
        modality_voxel_counts[mod].append(v_count)
    
    # Get unique modalities
    unique_mods = sorted(modality_dscs.keys())
    
    # Create figure with 2x2 subplots
    fig, axes = plt.subplots(2, 2, figsize=(18, 12))
    
    # For boxplots
    metric_data = {
        'DSC': [modality_dscs[mod] for mod in unique_mods],
        'NSD': [modality_nsds[mod] for mod in unique_mods],
        'Voxel Size': [modality_voxel_sizes[mod] for mod in unique_mods],
        'Voxel Count': [modality_voxel_counts[mod] for mod in unique_mods]
    }
    
    titles = ['DSC by Modality', 'NSD by Modality', 
              'Voxel Size by Modality', 'Voxel Count by Modality']
    ylabels = ['DSC Score', 'NSD Score', 'Voxel Size (mm³)', 'Voxel Count']
    
    # Colors for different modalities
    colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightyellow', 'lightgrey']
    
    # Create each subplot
    for i, (ax, title, ylabel, key) in enumerate(zip(
            axes.flatten(), titles, ylabels, metric_data.keys())):
        
        # Log scale for voxel count
        if key == 'Voxel Count':
            ax.set_yscale('log')
        
        # Create boxplot
        box = ax.boxplot(metric_data[key], patch_artist=True)
        ax.set_xticklabels(unique_mods)
        ax.set_title(title)
        ax.set_ylabel(ylabel)
        ax.grid(axis='y', alpha=0.3)
        
        # Add color to boxes
        for j, b in enumerate(box['boxes']):
            b.set(facecolor=colors[j % len(colors)])
    
    plt.tight_layout()
    plt.show()
    
    # Print statistics per modality
    print("Statistics by Modality:")
    print("-----------------------")
    
    for mod in unique_mods:
        print(f"\n{mod} Modality (n={len(modality_dscs[mod])}):")
        print(f"  DSC - Mean: {np.mean(modality_dscs[mod]):.3f}, Median: {np.median(modality_dscs[mod]):.3f}")
        print(f"  NSD - Mean: {np.mean(modality_nsds[mod]):.3f}, Median: {np.median(modality_nsds[mod]):.3f}")
        print(f"  Voxel Size - Mean: {np.mean(modality_voxel_sizes[mod]):.3f}, Median: {np.median(modality_voxel_sizes[mod]):.3f}")
        print(f"  Voxel Count - Mean: {np.mean(modality_voxel_counts[mod]):.3f}, Median: {np.median(modality_voxel_counts[mod]):.3f}")

# %%
plot_stats_by_modality(modalities, dscs, nsds, voxel_sizes, voxel_count)
# Out:
# Statistics by Modality:
# -----------------------
#
# CT Modality (n=102):
#   DSC - Mean: 0.824, Median: 0.855
#   NSD - Mean: 0.855, Median: 0.886
#   Voxel Size - Mean: 2.707, Median: 3.375
#   Voxel Count - Mean: 21163084.353, Median: 13631635.000
#
# MR Modality (n=107):
#   DSC - Mean: 0.649, Median: 0.681
#   NSD - Mean: 0.760, Median: 0.799
#   Voxel Size - Mean: 3.046, Median: 1.000
#   Voxel Count - Mean: 2520541.944, Median: 2102828.000
#
# PE Modality (n=7):
#   DSC - Mean: 0.754, Median: 0.826
#   NSD - Mean: 0.683, Median: 0.696
#   Voxel Size - Mean: 32.584, Median: 12.441
#   Voxel Count - Mean: 11277531.429, Median: 7680000.000
#
# US Modality (n=11):
#   DSC - Mean: 0.839, Median: 0.848
#   NSD - Mean: 0.853, Median: 0.847
#   Voxel Size - Mean: 0.095, Median: 0.095
#   Voxel Count - Mean: 5938103.636, Median: 5908608.000
